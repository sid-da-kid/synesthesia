# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython import display

x = np.linspace(0, 2*np.pi, 100)

fig = plt.figure()

lines = plt.plot([])
line = lines[0]

def update(frame):
    # update plot
    y = np.sin(x + 2*np.pi * frame/100)
    line.set_data((x, y))


anim = FuncAnimation(fig, update, frames=100, interval=20)
video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 21
#      17     line.set_data((x, y))
#      20 anim = FuncAnimation(fig, update, frames=100, interval=20)
# ---> 21 video = anim.to_html5_video()
#      22 html = display.HTML(video)
#      23 display.display(html)
#
# File c:\Users\nairs\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\animation.py:1285, in Animation.to_html5_video(self, embed_limit)
#    1282 path = Path(tmpdir, "temp.m4v")
#    1283 # We create a writer manually so that we can get the
#    1284 # appropriate size for the tag
# -> 1285 Writer = writers[mpl.rcParams['animation.writer']]
#    1286 writer = Writer(codec='h264',
#    1287                 bitrate=mpl.rcParams['animation.bitrate'],
#    1288                 fps=1000. / self._interval)
#    1289 self.save(str(path), writer=writer)
#
# File c:\Users\nairs\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\animation.py:148, in MovieWriterRegistry.__getitem__(self, name)
#     146 if self.is_available(name):
#     147     return self._registered[name]
# --> 148 raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available
